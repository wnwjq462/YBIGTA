# %% [markdown]
# 18기 컴퓨터과학과 박다현 WordCloud 과제

# %%
from wordcloud import WordCloud

# %%
sudal_text = open("/Users/mac/Desktop/와이빅타/교육세션/2021. 2. 4 (목) wordcloud-konlpy/세션자료/실습/data/수달.txt","r").read()
sudal_text
# Out:
# "수달 사생활 엿보기 59\n수달 사생활 엿보기\n권경자 ․ 한성용 (한국수달연구센터)\n누구든 물에 사는 동물에는 어떤 것이 있느냐는 질문을 받게 된다면 아\n마 가장 먼저 물고기를 떠올릴 것이다. 어느 하천에서나 쉽게 볼 수 있고,\n어린 시절 한 번쯤은 그 물고기를 잡으러 여기저기 첨벙거리던 기억을 추\n억할 것이다. 그 외엔 또 무엇이 있을까. 유유자적 물속을 도도하게 걷는\n새도 있을 것이고, 이름 모를 수많은 곤충과 다슬기도 쉽게 떠올릴 것이다.\n그럼 이게 다 일까. 아마 이 동물의 이름을 제일 먼저 생각해 내는 사람은\n그리 많지 않을 것\n이다. 어쩌면 존재\n여부 자체도 알지\n못하는 이도 있을\n것이다. 야행성인\n지라 우리가 야생\n에서 이 동물의 모\n습을 쉽게 볼 수\n없다는 것도 이유\n60 재미있는 야생 동·식물 이야기\n가 될 수 있을 것이다. 물속 세계의 최상위에 존재하면서 수환경의 지표종\n으로서의 역할을 담당하고 있는 이 동물에 대해 우리는 얼마나 알고 있을\n까. 쉬이 그 모습을 허락하지 않는 동물, 수달들의 사적인 이야기를 들어보\n자.\n∵ 내가 바로 수달이야\n수달(水獺)이란 물에 사는 족제비란 뜻의 이름이다. 이름에서 보듯 그만\n큼 형체가 족제비와 비슷하단 말일 것이고, 또한 물과 밀접한 관계를 갖고\n있는 이들의 습성을 엿볼 수 있다. 수달은 분류학적으로 식육목, 족제비과\n에 속해 있다. 여기엔 많이 들어본 오소리, 족제비, 담비 등이 수달의 친척\n으로 함께 있다. 수달은 전 세계적으로 13종이 서식 분포하고 있으며, 각\n각의 종이 갖는 특성이나 지역에 따라 해달이나 큰수달, 북미수달 처럼 고\n유의 이름을 갖게 되었다. 13종 가운데 우리나라에는 유라시아수달(Eurasian Otter, Lutra lutra) 한 종만이 서식하고 있다. 간혹 바다에서 해달을\n봤다는 사람들을 만나게 된다. 바다에서 헤엄치던 수달은 과연 해달일까.\n바다에 살면 다 해달일까. 그렇지 않다. 해달은 알래스카와 캘리포니아 연
# ...

# %%
sudalwc = WordCloud(font_path="/Users/mac/Desktop/와이빅타/교육세션/2021. 2. 4 (목) wordcloud-konlpy/세션자료/실습/data/HoonlefthanderR.otf", background_color = "white")
sudalwc.generate(sudal_text)
# Out:
# In /anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# ...

# %%
sudalwc.words_
# Out:
# {'있다': 1.0,
#  '수달은': 0.6857142857142857,
#  '수달이': 0.6571428571428571,
#  '있는': 0.6285714285714286,
#  '수달의': 0.45714285714285713,
#  '한다': 0.45714285714285713,
#  '수달': 0.4,
#  '것이다': 0.37142857142857144,
#  '수달을': 0.34285714285714286,
#  '어린': 0.2857142857142857,
#  '있어': 0.2571428571428571,
#  '되면': 0.2571428571428571,
#  '있었다': 0.22857142857142856,
#  '수달 사생활': 0.22857142857142856,
#  '사생활 엿보기': 0.22857142857142856,
#  '된다': 0.2,
#  '재미있는 야생': 0.2,
#  '야생 식물': 0.2,
#  '식물 이야기': 0.2,
#  '사는': 0.17142857142857143,
#  '쉽게': 0.17142857142857143,
#  '있고': 0.17142857142857143,
#  '있을': 0.17142857142857143,
#  '하는': 0.17142857142857143,
#  '때문에': 0.17142857142857143,
#  '물에서': 0.17142857142857143,
#  '먹이를': 0.17142857142857143,
#  '물속에': 0.17142857142857143,
#  '않은': 0.17142857142857143,
#  '작은': 0.17142857142857143,
#  '헤엄을': 0.17142857142857143,
#  '않고': 0.17142857142857143,
#  '물고기를': 0.14285714285714285,
#  '우리가': 0.14285714285714285,
#  '결국': 0.14285714285714285,
# ...

# %%
stopwords = ["있다","있는","한다","것이다","있어","되면","있었다","된다","있고","있을","하는","때문에","않은","않고","우리가","아닌가","것을","여전히","이후","그런데"]

# %%
sudalwc = WordCloud(font_path="/Users/mac/Desktop/와이빅타/교육세션/2021. 2. 4 (목) wordcloud-konlpy/세션자료/실습/data/HoonlefthanderR.otf", background_color = "white",
                   stopwords=stopwords)
sudalwc.generate(sudal_text)
sudalwc.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x128ECA780>

# %%
from PIL import Image,ImageFilter

# %%
Image.open("/Users/mac/Desktop/와이빅타/교육세션/2021. 2. 4 (목) wordcloud-konlpy/세션자료/실습/data/mask2.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1162x1283 at 0x128FB6CF8>

# %%
import numpy as np
mask_array = np.array(Image.open("/Users/mac/Desktop/와이빅타/교육세션/2021. 2. 4 (목) wordcloud-konlpy/세션자료/실습/data/mask2.png").resize((600,600)))
mask_array
# Out:
# array([[[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
# ...

# %%
sudalwc = WordCloud(font_path="/Users/mac/Desktop/와이빅타/교육세션/2021. 2. 4 (목) wordcloud-konlpy/세션자료/실습/data/HoonlefthanderR.otf", background_color = "white",
                   stopwords=stopwords, mask = mask_array)
sudalwc.generate(sudal_text)
sudalwc.to_image()
sudalwc.to_file("my_sudal.png")
